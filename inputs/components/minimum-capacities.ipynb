# %%
require(data.table)
require(ggplot2)
# Out:
# Loading required package: data.table
# Loading required package: ggplot2

# %%
prod <- fread("Production-Costs-2016Dollars.tsv")
deli <- fread("Delivery-Costs-2016Dollars.tsv")
comp <- rbind(prod, deli)

# %%
comp[, .(`Minimum Capacity [kg/yr]`=min(`Capacity [kg/yr]`)), by=`Technology`]
# Out:
#    Technology                                Minimum Capacity [kg/yr]
# 1  Central Biomass Gasification               7300365
# 2  Central Coal Gasification (no CCS)        89964470
# 3  Central Coal Gasification w/CCS           89964470
# 4  Central Grid Electrolysis (Solid Oxide)   18250000
# 5  Central Grid Electrolysis (PEM)           18250000
# 6  Central Natural Gas Reforming (no CCS)    85775365
# 7  Central Natural Gas Reforming (w/CCS)     94900365
# 8  Onsite Electrolysis (PEM)                   547500
# 9  Onsite Natural Gas Reforming                182865
# 10 Central Photoelectrochemical Type 2         365000
# 11 Central Photoelectrochemical Type 4         365000
# 12 GH2 1000bar Pipeline (distribution)          10000
# 13 GH2 1000bar Pipeline Compressor              10000
# 14 GH2 1000bar Pipeline Station (700bar)        18250
# 15 GH2 350bar Pipeline (distribution)           10000
# 16 GH2 350bar Pipeline Compressor               10000
# ...
